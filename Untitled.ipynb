# %% [markdown]
# # Texto: Cantos Fantasias

# %%
import pandas as pd

# %%
df = pd.read_csv('cantos_fantasias.csv')
df.head()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Input In [2], in <cell line: 1>()
# ----> 1 df = pd.read_csv('cantos_fantasias.csv')
#       2 df.head()
#
# File ~/Pessoal/repos/data-pipeline_text/venv/lib/python3.10/site-packages/pandas/util/_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# File ~/Pessoal/repos/data-pipeline_text/venv/lib/python3.10/site-packages/pandas/io/parsers/readers.py:680, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, error_bad_lines, warn_bad_lines, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
#     665 kwds_defaults = _refine_defaults_read(
#     666     dialect,
#     667     delimiter,
#    (...)
#     676     defaults={"delimiter": ","},
#     677 )
#     678 kwds.update(kwds_defaults)
# --> 680 return _read(filepath_or_buffer, kwds)
#
# File ~/Pessoal/repos/data-pipeline_text/venv/lib/python3.10/site-packages/pandas/io/parsers/readers.py:575, in _read(filepath_or_buffer, kwds)
#     572 _validate_names(kwds.get("names", None))
#     574 # Create the parser.
# --> 575 parser = TextFileReader(filepath_or_buffer, **kwds)
#     577 if chunksize or iterator:
#     578     return parser
#
# File ~/Pessoal/repos/data-pipeline_text/venv/lib/python3.10/site-packages/pandas/io/parsers/readers.py:934, in TextFileReader.__init__(self, f, engine, **kwds)
#     931     self.options["has_index_names"] = kwds["has_index_names"]
#     933 self.handles: IOHandles | None = None
# --> 934 self._engine = self._make_engine(f, self.engine)
#
# File ~/Pessoal/repos/data-pipeline_text/venv/lib/python3.10/site-packages/pandas/io/parsers/readers.py:1218, in TextFileReader._make_engine(self, f, engine)
#    1214     mode = "rb"
#    1215 # error: No overload variant of "get_handle" matches argument types
#    1216 # "Union[str, PathLike[str], ReadCsvBuffer[bytes], ReadCsvBuffer[str]]"
#    1217 # , "str", "bool", "Any", "Any", "Any", "Any", "Any"
# -> 1218 self.handles = get_handle(  # type: ignore[call-overload]
#    1219     f,
#    1220     mode,
#    1221     encoding=self.options.get("encoding", None),
#    1222     compression=self.options.get("compression", None),
#    1223     memory_map=self.options.get("memory_map", False),
#    1224     is_text=is_text,
#    1225     errors=self.options.get("encoding_errors", "strict"),
#    1226     storage_options=self.options.get("storage_options", None),
#    1227 )
#    1228 assert self.handles is not None
#    1229 f = self.handles.handle
#
# File ~/Pessoal/repos/data-pipeline_text/venv/lib/python3.10/site-packages/pandas/io/common.py:786, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     781 elif isinstance(handle, str):
#     782     # Check whether the filename is to be opened in binary mode.
#     783     # Binary mode does not support 'encoding' and 'newline'.
#     784     if ioargs.encoding and "b" not in ioargs.mode:
#     785         # Encoding
# --> 786         handle = open(
#     787             handle,
#     788             ioargs.mode,
#     789             encoding=ioargs.encoding,
#     790             errors=errors,
#     791             newline="",
#     792         )
#     793     else:
#     794         # Binary mode
#     795         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'cantos_fantasias.csv'

# %%
df.shape
# Out:
# (2323, 10)

# %%
lema__value_counts = df.lemma.value_counts()
lema__value_counts.head()
# Out:
# ,       185
# \n      147
# o       141
# de o    126
# e        75
# Name: lemma, dtype: int64

# %%
lemma_value_counts_percent = df.lemma.value_counts(normalize=True)
lemma_value_counts_percent.head()
# Out:
# ,       0.079638
# \n      0.063280
# o       0.060697
# de o    0.054240
# e       0.032286
# Name: lemma, dtype: float64

# %% [markdown]
# A distribuição de frequência da variável lemma não nos diz muita coisa. Talvez podemos melhorar esse cenário se excluirmos potuação.

# %%
df__no_pontuation = df[df['is_punct'] == False]
df__no_pontuation_no_space = df__no_pontuation[df['tag'] != 'SPACE']
df__no_pontuation_no_space.head(40)
# Out:
# /var/folders/t5/kblv68dx43g86nwndpbwdp300000gp/T/ipykernel_20343/3687866651.py:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df__no_pontuation_no_space = df__no_pontuation[df['tag'] != 'SPACE']
#     Unnamed: 0        text       lemma    pos    tag  \
# 0            0    Fagundes    Fagundes  PROPN  PROPN
# 1            1      Varela      Varela  PROPN  PROPN
# 3            3      Cantos      Cantos   NOUN   NOUN
# 4            4           e           e  CCONJ  CCONJ
# 5            5   fantasias    fantasia   NOUN   NOUN
# 7            7        Aqui        aqui    ADV    ADV
# 8            8       temos         ter   VERB   VERB
# 9            9          um          um    DET    DET
# 10          10       livro       livro   NOUN   NOUN
# 11          11          do        de o    ADP    ADP
# 12          12         Sr.         Sr.   NOUN   NOUN
# 13          13          F.          F.  PROPN  PROPN
# 14          14      Varela      Varela  PROPN  PROPN
# 16          16         que         que   PRON   PRON
# 17          17           é         ser    AUX    AUX
# 18          18          ao         a o    ADP    ADP
# 19          19       mesmo       mesmo    ADJ    ADJ
# 20          20       tempo       tempo   NOUN   NOUN
# 21          21         uma          um    DET    DET
# 22          22  realização  realização   NOUN   NOUN
# 23          23           e           e  CCONJ  CCONJ
# 25          25         uma          um    NUM    NUM
# 27          27    promessa    promessa   NOUN   NOUN
# 30          30     realiza    realizar   VERB   VERB
# 31          31          as           o    DET    DET
# 32          32  esperanças   esperança   NOUN   NOUN
# 33          33         das        de o    ADP    ADP
# 34          34    Noturnas    Noturnas  PROPN  PROPN
# 35          35           e           e  CCONJ  CCONJ
# 36          36         das        de o    ADP    ADP
# 37          37       Vozes       Vozes  PROPN  PROPN
# 38          38          da        de o    ADP    ADP
# 39          39     América     América  PROPN  PROPN
# 41          41           e           e  CCONJ  CCONJ
# 43          43     promete    prometer   VERB   VERB
# 44          44       ainda       ainda    ADV    ADV
# 45          45    melhores         bom    ADJ    ADJ
# 46          46     páginas      página   NOUN   NOUN
# 47          47          no        em o    ADP    ADP
# 48          48      futuro      futuro   NOUN   NOUN
#
#                                                 morph ent_type  is_punct  \
# 0                             Gender=Masc|Number=Sing      PER     False
# 1                                         Number=Sing      PER     False
# 3                             Gender=Masc|Number=Plur      NaN     False
# 4                                                 NaN      NaN     False
# 5                              Gender=Fem|Number=Plur      NaN     False
# 7                                                 NaN      NaN     False
# 8   Mood=Ind|Number=Plur|Person=1|Tense=Pres|VerbF...      NaN     False
# 9   Definite=Ind|Gender=Masc|Number=Sing|PronType=Art      NaN     False
# 10                            Gender=Masc|Number=Sing      NaN     False
# 11  Definite=Def|Gender=Masc|Number=Sing|PronType=Art      NaN     False
# 12                            Gender=Masc|Number=Sing      PER     False
# 13                            Gender=Masc|Number=Sing      PER     False
# 14                                        Number=Sing      PER     False
# 16               Gender=Masc|Number=Sing|PronType=Rel      NaN     False
# 17  Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbF...      NaN     False
# 18  Definite=Def|Gender=Masc|Number=Sing|PronType=Art      NaN     False
# 19                            Gender=Masc|Number=Sing      NaN     False
# 20                            Gender=Masc|Number=Sing      NaN     False
# 21   Definite=Ind|Gender=Fem|Number=Sing|PronType=Art      NaN     False
# 22                             Gender=Fem|Number=Sing      NaN     False
# 23                                                NaN      NaN     False
# 25                                       NumType=Card      NaN     False
# 27                             Gender=Fem|Number=Sing      NaN     False
# 30  Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbF...      NaN     False
# 31   Definite=Def|Gender=Fem|Number=Plur|PronType=Art      NaN     False
# 32                             Gender=Fem|Number=Plur      NaN     False
# 33   Definite=Def|Gender=Fem|Number=Plur|PronType=Art      NaN     False
# 34                             Gender=Fem|Number=Plur     MISC     False
# 35                                                NaN      NaN     False
# 36   Definite=Def|Gender=Fem|Number=Plur|PronType=Art      NaN     False
# 37                             Gender=Fem|Number=Plur     MISC     False
# 38   Definite=Def|Gender=Fem|Number=Sing|PronType=Art     MISC     False
# 39                             Gender=Fem|Number=Sing     MISC     False
# 41                                                NaN      NaN     False
# 43  Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbF...      NaN     False
# 44                                                NaN      NaN     False
# 45                             Gender=Fem|Number=Plur      NaN     False
# 46                             Gender=Fem|Number=Plur      NaN     False
# 47  Definite=Def|Gender=Masc|Number=Sing|PronType=Art      NaN     False
# 48                            Gender=Masc|Number=Sing      NaN     False
#
#           dep  sentiment
# 0        ROOT        0.0
# 1   flat:name        0.0
# 3       appos        0.0
# 4          cc        0.0
# 5        conj        0.0
# 7      advmod        0.0
# 8   parataxis        0.0
# 9         det        0.0
# 10        obj        0.0
# 11       case        0.0
# 12       nmod        0.0
# 13      appos        0.0
# 14  flat:name        0.0
# 16      nsubj        0.0
# 17        cop        0.0
# 18       case        0.0
# 19       amod        0.0
# 20        dep        0.0
# 21        det        0.0
# 22        obj        0.0
# 23         cc        0.0
# 25        det        0.0
# 27      appos        0.0
# 30       ROOT        0.0
# 31        det        0.0
# 32        obj        0.0
# 33       case        0.0
# 34       nmod        0.0
# 35         cc        0.0
# 36       case        0.0
# 37       conj        0.0
# 38       case        0.0
# 39       nmod        0.0
# 41         cc        0.0
# 43       conj        0.0
# 44     advmod        0.0
# 45       amod        0.0
# 46        obj        0.0
# 47       case        0.0
# 48       nmod        0.0

# %%
df__no_pontuation_no_space.shape
# Out:
# (1864, 10)

# %%
lema_distr_freq = df__no_pontuation_no_space.lemma.value_counts(normalize=True)
lema_distr_freq.head(10)
# Out:
# o       0.075644
# de o    0.067597
# e       0.040236
# de      0.039700
# que     0.031652
# um      0.027361
# ser     0.026824
# não     0.014485
# em o    0.012876
# seu     0.012339
# Name: lemma, dtype: float64

# %%
pos_distr_freq = df__no_pontuation_no_space.pos.value_counts(normalize=True)
pos_distr_freq.head(10)
# Out:
# NOUN     0.244099
# ADP      0.163090
# DET      0.134120
# VERB     0.108906
# ADJ      0.078326
# ADV      0.061159
# PRON     0.055258
# CCONJ    0.051502
# PROPN    0.050429
# AUX      0.028970
# Name: pos, dtype: float64

# %%
dep_distr_freq = df__no_pontuation_no_space.dep.value_counts(normalize=True)
dep_distr_freq.head(10)
# Out:
# case      0.160944
# det       0.134657
# nmod      0.091202
# obj       0.068133
# conj      0.060622
# nsubj     0.060086
# amod      0.058476
# advmod    0.054185
# cc        0.049356
# obl       0.042382
# Name: dep, dtype: float64
